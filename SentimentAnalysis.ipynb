# %% [markdown]
# Python Code to Perform Sentiment Analysis

# %%
##import required libraries and define functions

import tweepy
import pandas as pd
import config
import re
from datetime import datetime
from datetime import timedelta
import snscrape.modules.twitter as snstwitter

from textblob import TextBlob
import matplotlib.pyplot as plt


tqdm.pandas()

##function for cleaning tweets
def cleanTweet(text):
    text=re.sub(r'@[A-Za-z0-9_]+','',text) ## remove @mentions
    text=re.sub(r'\#','',text)   ## remove hash tag
    text=re.sub(r'RT[\s]+','',text) ##remove RT
    text=re.sub(r'https?:\/\/\S+','',text) ##remove hyperlink
    text=re.sub(r'\n',' ',text) ##remove next line character
    return text

##functions to get subjectivity and Polarity
def getSubjectivity(text):
    return TextBlob(str(text)).sentiment.subjectivity

def getPolarity(text):
    return TextBlob(str(text)).sentiment.polarity


##function to get analysis based on score
def getAnalysis(score):
    if float(score) == None:
        raise Exception("Null Object Passed")

    if float(score) < 0:
        return 'Negative'
    elif float(score) == 0:
        return 'Neutral'
    else:
        return 'Positive'

##client = tweepy.Client(bearer_token=config.twitter_bearertoken)

# %%
##scrape data from twitter
query = "Joe Biden until:2021-01-01 since:2020-01-01"
max_tweets = 50000
tweet_content=[]

for i, tweets in enumerate(snstwitter.TwitterSearchScraper(query).get_items()):
    if i == max_tweets:
        break
    else:
        tweet_content.append((str(tweets.id), tweets.date, str(tweets.content), str(
            tweets.lang), str(tweets.sourceLabel), str(query),  datetime.utcnow()))

df = pd.DataFrame(tweet_content, columns=['tweet_id', 'tweet_created_at', 'tweet_text',
                  'tweet_lang', 'tweet_source', 'tweets_search_query', 'tweets_scrapped'])

tweet_content = None

# %%
df['tweet_clean_text'] = df['tweet_text'].apply(cleanTweet)

##apply functions to get subjectivity and polarity
df['tweet_Subjectivity'] = df['tweet_clean_text'].apply(getSubjectivity)
df['tweet_Polarity'] = df['tweet_clean_text'].apply(getPolarity)
df['tweet_Analysis'] = df['tweet_Polarity'].apply(getAnalysis)

# %%
df
# Out:
#                   tweet_id    tweet_created_at  \
# 0      1381034237550268420 2021-04-10 23:59:55
# 1      1381034234870046722 2021-04-10 23:59:54
# 2      1381034225894256647 2021-04-10 23:59:52
# 3      1381034222777991180 2021-04-10 23:59:51
# 4      1381034221163143171 2021-04-10 23:59:51
# ...                    ...                 ...
# 99995  1344516329676677122 2020-12-31 05:30:47
# 99996  1344516324341460994 2020-12-31 05:30:46
# 99997  1344516315927687168 2020-12-31 05:30:44
# 99998  1344516308503846914 2020-12-31 05:30:42
# 99999  1344516302531125248 2020-12-31 05:30:41
#
#                                               tweet_text tweet_lang  \
# 0      Joe Biden is such a manipulative asshole bro. ...         en
# 1                                     @POTUS Jack ass!!!         en
# 2      @DaniiellePa Harris. After she dropped out, my...         en
# 3            @POTUS What???????? https://t.co/BqaMYGt421         en
# 4                         @POTUS https://t.co/FTT8tfMd27        qme
# ...                                                  ...        ...
# 99995  @JoeBiden “Let me wave my magic wand! Ignore t...         en
# 99996                     @dawndaledoxidoc @JoeBiden Yup        und
# 99997  @JoeBiden @realDonaldTrump\n\nB6lJQub5TXciIIfg...         in
# 99998  @Exclusiv1chat @JoeBiden @BidenInaugural Well ...         en
# 99999  @KamalaHarris @JoeBiden You stole it in Novemb...         en
#
#               tweet_source                          tweets_search_query  \
# 0       Twitter for iPhone  Joe Biden until:2021-04-11 since:2021-01-01
# 1       Twitter for iPhone  Joe Biden until:2021-04-11 since:2021-01-01
# 2          Twitter Web App  Joe Biden until:2021-04-11 since:2021-01-01
# 3      Twitter for Android  Joe Biden until:2021-04-11 since:2021-01-01
# 4       Twitter for iPhone  Joe Biden until:2021-04-11 since:2021-01-01
# ...                    ...                                          ...
# 99995   Twitter for iPhone  Joe Biden until:2021-01-01 since:2020-01-01
# 99996   Twitter for iPhone  Joe Biden until:2021-01-01 since:2020-01-01
# 99997  Twitter for Android  Joe Biden until:2021-01-01 since:2020-01-01
# 99998      Twitter Web App  Joe Biden until:2021-01-01 since:2020-01-01
# 99999   Twitter for iPhone  Joe Biden until:2021-01-01 since:2020-01-01
#
#               tweets_scrapped  \
# 0     2022-08-28 20:09:32.302
# 1     2022-08-28 20:09:32.302
# 2     2022-08-28 20:09:32.302
# 3     2022-08-28 20:09:32.302
# 4     2022-08-28 20:09:32.302
# ...                       ...
# 99995 2022-08-28 21:48:52.887
# 99996 2022-08-28 21:48:52.887
# 99997 2022-08-28 21:48:52.887
# 99998 2022-08-28 21:48:53.507
# 99999 2022-08-28 21:48:53.507
#
#                                         tweet_clean_text  tweet_Subjectivity  \
# 0      Joe Biden is such a manipulative asshole bro. ...            0.518333
# 1                                            Jack ass!!!            0.000000
# 2       Harris. After she dropped out, my favorite ad...            1.000000
# 3                                          What????????             0.000000
# 4                                                                   0.000000
# ...                                                  ...                 ...
# 99995   “Let me wave my magic wand! Ignore the fact t...            0.850000
# 99996                                                Yup            0.000000
# 99997       B6lJQub5TXciIIfg6HbxfKC/1pv+PehDz0WuV8w/N5k=            0.000000
# 99998                               Well put, thank you.            0.000000
# 99999                        You stole it in November!!!            0.000000
#
#        tweet_Polarity tweet_Analysis
# 0            -0.14500       Negative
# 1             0.00000        Neutral
# 2             0.25000       Positive
# 3             0.00000        Neutral
# 4             0.00000        Neutral
# ...               ...            ...
# 99995         0.50625       Positive
# 99996         0.00000        Neutral
# 99997         0.00000        Neutral
# 99998         0.00000        Neutral
# 99999         0.00000        Neutral
#
# [100000 rows x 11 columns]

# %% [markdown]
# Code to Dump data into Mongodb

# %%
###Dump collected data into mongodb

from pymongo import MongoClient
import config

client=MongoClient(config.mdb_string)
mydatabase=client[config.mdb_db]
collection = mydatabase["JoeBiden"]
dump_df=df
collection.insert_many(dump_df.to_dict("records"))

# %%
##load data from mongodb to pd
from pymongo import MongoClient
import pandas as pd
import config

client = MongoClient(config.mdb_string)
mydatabase = client[config.mdb_db]
collection = mydatabase["JoeBiden"]
all_record=collection.find()

df = pd.DataFrame(list(collection.find()))
df=df.drop(columns=['_id'])
df
# Out:
#                   tweet_id    tweet_created_at  \
# 0      1381034237550268420 2021-04-10 23:59:55
# 1      1381034234870046722 2021-04-10 23:59:54
# 2      1381034225894256647 2021-04-10 23:59:52
# 3      1381034222777991180 2021-04-10 23:59:51
# 4      1381034221163143171 2021-04-10 23:59:51
# ...                    ...                 ...
# 99995  1344516329676677122 2020-12-31 05:30:47
# 99996  1344516324341460994 2020-12-31 05:30:46
# 99997  1344516315927687168 2020-12-31 05:30:44
# 99998  1344516308503846914 2020-12-31 05:30:42
# 99999  1344516302531125248 2020-12-31 05:30:41
#
#                                               tweet_text tweet_lang  \
# 0      Joe Biden is such a manipulative asshole bro. ...         en
# 1                                     @POTUS Jack ass!!!         en
# 2      @DaniiellePa Harris. After she dropped out, my...         en
# 3            @POTUS What???????? https://t.co/BqaMYGt421         en
# 4                         @POTUS https://t.co/FTT8tfMd27        qme
# ...                                                  ...        ...
# 99995  @JoeBiden “Let me wave my magic wand! Ignore t...         en
# 99996                     @dawndaledoxidoc @JoeBiden Yup        und
# 99997  @JoeBiden @realDonaldTrump\n\nB6lJQub5TXciIIfg...         in
# 99998  @Exclusiv1chat @JoeBiden @BidenInaugural Well ...         en
# 99999  @KamalaHarris @JoeBiden You stole it in Novemb...         en
#
#               tweet_source                          tweets_search_query  \
# 0       Twitter for iPhone  Joe Biden until:2021-04-11 since:2021-01-01
# 1       Twitter for iPhone  Joe Biden until:2021-04-11 since:2021-01-01
# 2          Twitter Web App  Joe Biden until:2021-04-11 since:2021-01-01
# 3      Twitter for Android  Joe Biden until:2021-04-11 since:2021-01-01
# 4       Twitter for iPhone  Joe Biden until:2021-04-11 since:2021-01-01
# ...                    ...                                          ...
# 99995   Twitter for iPhone  Joe Biden until:2021-01-01 since:2020-01-01
# 99996   Twitter for iPhone  Joe Biden until:2021-01-01 since:2020-01-01
# 99997  Twitter for Android  Joe Biden until:2021-01-01 since:2020-01-01
# 99998      Twitter Web App  Joe Biden until:2021-01-01 since:2020-01-01
# 99999   Twitter for iPhone  Joe Biden until:2021-01-01 since:2020-01-01
#
#               tweets_scrapped
# 0     2022-08-28 20:09:32.302
# 1     2022-08-28 20:09:32.302
# 2     2022-08-28 20:09:32.302
# 3     2022-08-28 20:09:32.302
# 4     2022-08-28 20:09:32.302
# ...                       ...
# 99995 2022-08-28 21:48:52.887
# 99996 2022-08-28 21:48:52.887
# 99997 2022-08-28 21:48:52.887
# 99998 2022-08-28 21:48:53.507
# 99999 2022-08-28 21:48:53.507
#
# [100000 rows x 7 columns]

# %%
from time import strftime


df['tweet_created_at'].apply(lambda x: x.strftime("%y%m")).unique()
# Out:
# array(['2104', '2112', '2208', '2012'], dtype=object)

# %%
import ntlk

# %%
from datetime import timedelta

timedelta(days=1)
# Out:
# datetime.timedelta(days=1)
